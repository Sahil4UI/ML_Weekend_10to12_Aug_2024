# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
homeData = pd.read_csv('SaratogaHouses.csv')

# %%
homeData.shape
# Out:
# (1728, 17)

# %%
homeData.head()
# Out:
#    Unnamed: 0   price  lotSize  age  landValue  livingArea  pctCollege  \
# 0           1  132500     0.09   42      50000         906          35
# 1           2  181115     0.92    0      22300        1953          51
# 2           3  109000     0.19  133       7300        1944          51
# 3           4  155000     0.41   13      18700        1944          51
# 4           5   86060     0.11    0      15000         840          51
#
#    bedrooms  fireplaces  bathrooms  rooms          heating      fuel  \
# 0         2           1        1.0      5         electric  electric
# 1         3           0        2.5      6  hot water/steam       gas
# 2         4           1        1.0      8  hot water/steam       gas
# 3         3           1        1.5      5          hot air       gas
# 4         2           0        1.0      3          hot air       gas
#
#                sewer waterfront newConstruction centralAir
# 0             septic         No              No         No
# ...

# %%
style.use('ggplot')#style -theme
plt.figure(figsize=(12,6)) #size of the plot
plt.scatter(homeData['livingArea'], homeData['price'])
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.title('Price W.R.T Living Area')
# Out:
# Text(0.5, 1.0, 'Price W.R.T Living Area')

# %%
import seaborn as sns

# %%
sns.countplot(x=homeData['centralAir'])
# Out:
# <Axes: xlabel='centralAir', ylabel='count'>

# %%
plt.boxplot(x=homeData['price'],notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12cc47b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12cc47d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12cc479d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12cc8c050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12cc8c190>],
#  'means': []}
